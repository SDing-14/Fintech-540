# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import missingno as msno

#read data
data=pd.read_csv('combined_dataset.csv')

# Check for missing values
missing_values = data.isnull().sum()

# Descriptive statistics
desc_stats = data.describe()

# For visualization, we will select a few columns
# Selecting columns for Apple Inc. (AAPL) as an example
selected_columns = ['AAPL_Log_Change', 'AAPL_High_Low_Spread', 'AAPL_Volume', 'AAPL_1hr_Moving_Average', 'AAPL_RSI']

# Extracting date from the timestamp for plotting
data['Date'] = pd.to_datetime(data['Unnamed: 0']).dt.date

# Plotting time series for selected columns
plt.figure(figsize=(15, 10))

for i, column in enumerate(selected_columns, 1):
    plt.subplot(len(selected_columns), 1, i)
    sns.lineplot(data=data, x='Date', y=column)
    plt.title(column)
    plt.tight_layout()

plt.show()

# %%
msno.matrix(data)
plt.show()

# %%
plt.figure(figsize=(15, 10))
for i, column in enumerate(selected_columns, 1):
    plt.subplot(len(selected_columns), 1, i)
    sns.histplot(data[column], kde=True)
    plt.title(f'Histogram of {column}')
    plt.tight_layout()

plt.show()

# %%
pairs_to_plot = [
    ('NASDAQ_Volatility', 'AAPL_High_Low_Spread'),
    ('NASDAQ_Volatility', 'AAPL_Volume'),
    ('NASDAQ_Volatility', 'AAPL_1hr_Moving_Average'),
    ('NASDAQ_Volatility', 'AAPL_RSI')
]

# 绘制散点图
for pair in pairs_to_plot:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=data, x=pair[0], y=pair[1])
    plt.title(f'Scatter Plot of {pair[0]} vs {pair[1]}')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/getlimits.py:502, in finfo.__new__(cls, dtype)
#     501 try:
# --> 502     dtype = numeric.dtype(dtype)
#     503 except TypeError:
#     504     # In case a float instance was given
#
# TypeError: 'NoneType' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 11
#       9 for pair in pairs_to_plot:
#      10     plt.figure(figsize=(8, 6))
# ---> 11     sns.scatterplot(data=data, x=pair[0], y=pair[1])
#      12     plt.title(f'Scatter Plot of {pair[0]} vs {pair[1]}')
#      13     plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/relational.py:614, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     611 p.map_style(markers=markers, order=style_order)
#     613 if ax is None:
# --> 614     ax = plt.gca()
#     616 if not p.has_xy_data:
#     617     return ax
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py:2309, in gca()
#    2307 @_copy_docstring_and_deprecators(Figure.gca)
#    2308 def gca():
# -> 2309     return gcf().gca()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/figure.py:1628, in FigureBase.gca(self)
#    1618 """
#    1619 Get the current Axes.
#    1620
#    (...)
#    1625 whether `.pyplot.get_fignums()` is empty.)
#    1626 """
#    1627 ax = self._axstack.current()
# -> 1628 return ax if ax is not None else self.add_subplot()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/figure.py:757, in FigureBase.add_subplot(self, *args, **kwargs)
#     754         args = tuple(map(int, str(args[0])))
#     755     projection_class, pkw = self._process_projection_requirements(
#     756         *args, **kwargs)
# --> 757     ax = projection_class(self, *args, **pkw)
#     758     key = (projection_class, pkw)
#     759 return self._add_axes_internal(ax, key)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:683, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     680 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     682 self._rasterization_zorder = None
# --> 683 self.clear()
#     685 # funcs used to format x and y - fall back on major formatters
#     686 self.fmt_xdata = None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:1395, in _AxesBase.clear(self)
#    1393     self.cla()
#    1394 else:
# -> 1395     self.__clear()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:1383, in _AxesBase.__clear(self)
#    1381     else:
#    1382         axis._set_scale("linear")
# -> 1383         axis._set_lim(0, 1, auto=True)
#    1384 self._update_transScale()
#    1386 self.stale = True
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1213, in Axis._set_lim(self, v0, v1, emit, auto)
#    1209     _api.warn_external(
#    1210         f"Attempting to set identical low and high {name}lims "
#    1211         f"makes transformation singular; automatically expanding.")
#    1212 reverse = bool(v0 > v1)  # explicit cast needed for python3.8+np.bool_.
# -> 1213 v0, v1 = self.get_major_locator().nonsingular(v0, v1)
#    1214 v0, v1 = self.limit_range_for_scale(v0, v1)
#    1215 v0, v1 = sorted([v0, v1], reverse=bool(reverse))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/ticker.py:1665, in Locator.nonsingular(self, v0, v1)
#    1651 def nonsingular(self, v0, v1):
#    1652     """
#    1653     Adjust a range as needed to avoid singularities.
#    1654
#    (...)
#    1663     - Otherwise, ``(v0, v1)`` is returned without modification.
#    1664     """
# -> 1665     return mtransforms.nonsingular(v0, v1, expander=.05)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/transforms.py:2863, in nonsingular(vmin, vmax, expander, tiny, increasing)
#    2860 vmin, vmax = map(float, [vmin, vmax])
#    2862 maxabsvalue = max(abs(vmin), abs(vmax))
# -> 2863 if maxabsvalue < (1e6 / tiny) * np.finfo(float).tiny:
#    2864     vmin = -expander
#    2865     vmax = expander
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/getlimits.py:505, in finfo.__new__(cls, dtype)
#     502     dtype = numeric.dtype(dtype)
#     503 except TypeError:
#     504     # In case a float instance was given
# --> 505     dtype = numeric.dtype(type(dtype))
#     507 obj = cls._finfo_cache.get(dtype)
#     508 if obj is not None:
#
# TypeError: 'NoneType' object is not callable
